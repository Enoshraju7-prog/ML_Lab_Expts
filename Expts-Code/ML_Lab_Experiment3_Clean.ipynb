# %% [markdown]
# <a href="https://colab.research.google.com/github/Enoshraju7-prog/ML_Lab_Expts/blob/main/Expts-Code/ML_Lab_Experiment3_Clean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MACHINE LEARNING FOR ELECTRONICS ENGINEERS LAB
# ## Experiment 3: Understanding Data Loading and Processing
# **Birla Institute of Technology and Science, Pilani, Hyderabad Campus**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
from sklearn.datasets import fetch_california_housing

# %% [markdown]
# ---
# ## Q1. Creating and Analyzing a Student DataFrame
#
# For the data given below:
#
# | Student_Name | Roll_No | Digital_elec | Sig_Sys | ML | Dept |
# |--------------|---------|--------------|---------|----|----- |
# | Amit         | 101     | 85           | 90      | 78 | CSE  |
# | Priya        | 102     | 92           | 88      | 85 | EEE  |
# | Rahul        | 103     | 78           | 85      | 80 | EEE  |
# | Sneha        | 104     | 88           | 92      | 88 | EEE  |
# | Vikram       | 105     | 95           | 89      | 82 | CSE  |
#
# Write a Python program to generate the above dataframe, and perform the following using the pandas library:
#
# a) After generating the above dataframe, convert the dataframe into a pandas dataframe
#
# b) Print the shape of the dataframe
#
# c) Print the column names (feature names) of the dataframe
#
# d) Print the first two rows of the dataframe
#
# e) Print the last two rows of the dataframe
#
# f) Print the descriptive statistics of the dataframe

# %%
# Create the data dictionary
data = {
    'Student_Name': ['Amit', 'Priya', 'Rahul', 'Sneha', 'Vikram'],
    'Roll_No': [101, 102, 103, 104, 105],
    'Digital_elec': [85, 92, 78, 88, 95],
    'Sig_Sys': [90, 88, 85, 92, 89],
    'ML': [78, 85, 80, 88, 82],
    'Dept': ['CSE', 'EEE', 'EEE', 'EEE', 'CSE']
}

# a) Convert to pandas DataFrame
df = pd.DataFrame(data)
print("DataFrame:")
print(df)

# b) Shape
print(f"\nShape: {df.shape}")

# c) Column names
print(f"\nColumn names: {df.columns.tolist()}")

# d) First two rows
print("\nFirst two rows:")
print(df.head(2))

# e) Last two rows
print("\nLast two rows:")
print(df.tail(2))

# f) Descriptive statistics
print("\nDescriptive statistics:")
print(df.describe())
# Out:
# DataFrame:
#   Student_Name  Roll_No  Digital_elec  Sig_Sys  ML Dept
# 0         Amit      101            85       90  78  CSE
# 1        Priya      102            92       88  85  EEE
# 2        Rahul      103            78       85  80  EEE
# 3        Sneha      104            88       92  88  EEE
# 4       Vikram      105            95       89  82  CSE
#
# Shape: (5, 6)
#
# Column names: ['Student_Name', 'Roll_No', 'Digital_elec', 'Sig_Sys', 'ML', 'Dept']
#
# First two rows:
#   Student_Name  Roll_No  Digital_elec  Sig_Sys  ML Dept
# 0         Amit      101            85       90  78  CSE
# 1        Priya      102            92       88  85  EEE
#
# Last two rows:
#   Student_Name  Roll_No  Digital_elec  Sig_Sys  ML Dept
# 3        Sneha      104            88       92  88  EEE
# 4       Vikram      105            95       89  82  CSE
#
# Descriptive statistics:
#           Roll_No  Digital_elec    Sig_Sys         ML
# count    5.000000      5.000000   5.000000   5.000000
# ...

# %% [markdown]
# ---
# ## Q2. Heart Failure Dataset Analysis
#
# Download the .csv file (filename: "heart_failure_clinical_records_dataset.csv") from the LMS and perform the following:
#
# a) Mount the drive and upload the .csv file into the Google Colab directory.
#
# b) Write a Python code to read the csv file using the pandas library
#
# c) After reading the file, print the first two rows of the dataset.
#
# d) Display the descriptive statistics of all the features of the dataset.
#
# e) Import the matplotlib library and plot a bar chart (use plt.bar command). Consider the target variable, death event = 1 (dead), from the dataset. Plot a bar graph showing the number of males and females for this given event.
#
# **Note:** In the data file, the Gender feature column uses '1' for male and '0' for female. A Death event of 1 indicates death occurred, and 0 indicates alive.

# %%
# a) Mount Google Drive (uncomment if file is in Drive)
# from google.colab import drive
# drive.mount('/content/drive')

# b) Read CSV file
# If file is uploaded to Colab session:
df_heart = pd.read_csv('/content/heart_failure_clinical_records_dataset.csv')

# If file is in Google Drive:
# df_heart = pd.read_csv('/content/drive/MyDrive/heart_failure_clinical_records_dataset.csv')

print("Dataset loaded successfully")
print(f"Shape: {df_heart.shape}")
# Out:
# Dataset loaded successfully
# Shape: (299, 13)

# %%
# c) First two rows
print("First two rows:")
print(df_heart.head(2))
# Out:
# First two rows:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  Gender  \
# 0                    1  265000.00               1.9           130       1
# 1                    0  263358.03               1.1           136       1
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1

# %%
# d) Descriptive statistics
print("Descriptive statistics:")
print(df_heart.describe())
# Out:
# Descriptive statistics:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
# e) Bar chart for death event by gender
# Filter data where DEATH_EVENT = 1
death_data = df_heart[df_heart['DEATH_EVENT'] == 1]

# Count males and females
gender_counts = death_data['Gender'].value_counts().sort_index()

# Create bar chart
plt.figure(figsize=(8, 6))
plt.bar(['Female', 'Male'], [gender_counts[0], gender_counts[1]], color=['pink', 'lightblue'])
plt.xlabel('Gender')
plt.ylabel('Number of Deaths')
plt.title('Death Event by Gender')
plt.grid(axis='y', alpha=0.3)
plt.show()

print(f"\nFemale deaths: {gender_counts[0]}")
print(f"Male deaths: {gender_counts[1]}")
# Out:
# Female deaths: 34
# Male deaths: 62

# %% [markdown]
# ---
# ## Q3. Image Processing with OpenCV
#
# Download the image file (name: "Lenna.png") from the LMS for the given problem:
#
# a) Mount and upload the image file into the Google Colab directory
#
# b) Import the OpenCV library to read the image file
#
# c) Convert the input image to RGB (by default, OpenCV loads images in BGR)
#
# d) Convert the obtained RGB image to a grayscale image
#
# e) Convert the above grayscale image to a binary image by considering a threshold value of 127.
#
# f) Import the matplotlib library and use the subplot command to plot the converted RGB image, grayscale, and binary image in a single figure.

# %%
# a) Upload image (uncomment if needed)
# from google.colab import files
# uploaded = files.upload()

# b) Read image using OpenCV
image = cv2.imread('Lenna.png')

# c) Convert BGR to RGB
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# d) Convert RGB to Grayscale
image_gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)

# e) Convert Grayscale to Binary (threshold = 127)
_, image_binary = cv2.threshold(image_gray, 127, 255, cv2.THRESH_BINARY)

# f) Plot all three images using subplots
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(image_rgb)
plt.title('RGB Image')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(image_gray, cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(image_binary, cmap='gray')
plt.title('Binary Image (Threshold=127)')
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Q4. California Housing Dataset from Scikit-Learn
#
# Some built-in (example) datasets are available in scikit learn library.
#
# a) From this scikit learn library, import the "California Housing dataset".
#
# **Hint:** You can use the following to import the data: `from sklearn.datasets import fetch_california_housing`.
# After importing, load the data.
#
# b) Using the pandas library, read the features (predictors) and target variables (response) from the loaded data. Store the features in the variable X and the target in the variable Y.
#
# c) Print the dimensions of the feature variable in the form m × n, where m is the number of samples and n is the number of features in the dataset.
#
# d) Determine whether the house pricing estimation is a regression or classification task.

# %%
# a) Load California Housing dataset
california = fetch_california_housing()
print("Dataset loaded successfully")

# b) Store features in X and target in Y
X = pd.DataFrame(california.data, columns=california.feature_names)
Y = pd.Series(california.target, name='Target')

print("\nFeatures (X):")
print(X.head())
print("\nTarget (Y):")
print(Y.head())

# c) Print dimensions
m, n = X.shape
print(f"\nDimensions: {m} × {n}")
print(f"Number of samples (m): {m}")
print(f"Number of features (n): {n}")

# d) Task type
print("\nTask Type: REGRESSION")
print("Reason: The target variable (house price) is a continuous numerical value, not discrete classes.")
# Out:
# Dataset loaded successfully
#
# Features (X):
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25
#
# Target (Y):
# 0    4.526
# 1    3.585
# 2    3.521
# 3    3.413
# 4    3.422
# Name: Target, dtype: float64
#
# Dimensions: 20640 × 8
# Number of samples (m): 20640
# Number of features (n): 8
#
# Task Type: REGRESSION
# Reason: The target variable (house price) is a continuous numerical value, not discrete classes.

# %% [markdown]
# ---
# ## Q5. Credit Card Fraud Detection Dataset
#
# Learn to access, download, and load data from the data explorer of Google Colab, and perform the following:
#
# a) Use the data explorer of Google Colab and download the "Credit Card Fraud Detection" dataset.
#
# b) Import the pandas library to read the features and target variables from the dataset. Save the features/predictor variables in the X variable and the target/response variable in the variable Y.
#
# c) Identify whether this dataset is for a regression or classification task.
#
# **Hint:** Learn the context of the data from the link provided in the data explorer while accessing this dataset.

# %%
# a) Load dataset
# Option 1: If downloaded from Kaggle
# df_fraud = pd.read_csv('creditcard.csv')

# Option 2: Using Kaggle API
# !pip install kaggle
# !kaggle datasets download -d mlg-ulb/creditcardfraud
# !unzip creditcardfraud.zip
# df_fraud = pd.read_csv('creditcard.csv')

# For demonstration, using a placeholder
print("To download: Go to Kaggle → Search 'Credit Card Fraud Detection' → Download")
print("Dataset: https://www.kaggle.com/mlg-ulb/creditcardfraud")

# Uncomment after downloading:
# df_fraud = pd.read_csv('creditcard.csv')
# print(f"Dataset loaded: {df_fraud.shape}")
# print(df_fraud.head())

# %%
# b) Separate features and target
# Uncomment after loading dataset:

# X = df_fraud.drop('Class', axis=1)  # Features (all columns except 'Class')
# Y = df_fraud['Class']  # Target (fraud or not)

# print(f"Features shape: {X.shape}")
# print(f"Target shape: {Y.shape}")
# print(f"\nTarget distribution:\n{Y.value_counts()}")

# %%
# c) Task type
print("Task Type: CLASSIFICATION")
print("\nReason:")
print("- The target variable 'Class' has two discrete values: 0 (Not Fraud) and 1 (Fraud)")
print("- The goal is to classify transactions into one of these two categories")
print("- This is a binary classification problem")
